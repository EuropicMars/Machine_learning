# %%
import numpy as np
import matplotlib.pyplot as plt
print(np.__version__)
plt.plot([1, 2, 3], [1, 4, 9])
plt.show()
# Out:
# 2.5.2

# %%
import numpy as np
import matplotlib.pyplot as plt
print(np.__version__)
plt.plot([1, 2, 3], [1, 4, 9])
plt.show()
# Out:
# 2.5.2
